# %%
import torch
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch import optim
import cv2
import os
import matplotlib.pyplot as plt

# %%
images = []

PATH = "./images/"
files = os.listdir(PATH)

print(files)
for i in range(10):
    
    f = cv2.imread(PATH+files[i])
    f = cv2.resize(f, (200,200))
    images += [f]
# Out:
# ['salt_noise.png', 'j.png', 'bell.jpg', 'lena.png', 'cubes.png', 'gamma1.jpg', 'FingerPrint.jpg', 'gamma2.jpg', 'window.jpeg', 'objects.png', 'chair.png', 'lotus.jpg', 'sudoku.jpeg', 'text.jpg', 'coins.jpg']

# %%
fig = plt.figure(figsize=(15,15))

for i in range(10):
    plt.subplot(4,4,i+1)
    
    plt.imshow(images[i], 'gray')
